# %%
from konlpy.tag import Mecab
import spacy
from collections import defaultdict

# %%
mecab = Mecab()
nlp = spacy.load("en_core_web_sm")

# %%
#define a class of translator to hold words, tags, and
